# %% [markdown]
# <h1>ImageDataGenerator untuk mengatasi ukuran gambar yang berbeda

# %%
#kita gunakan dataset chessman yang disediakan oleh dicoding
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2022-11-15 15:31:20--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2022-11-15 15:31:20--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   299MB/s    in 0.2s
#
# 2022-11-15 15:31:25 (299 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %% [markdown]
# ektrak dataset yang sudah diunduh karena masih dalam bentuk file zip

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# Gunakan fungsi listdir dari kelas os untuk melihat direktori yang terdapat pada dataset.

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Bishop', 'Queen', 'Knight', 'Rook', 'King', 'Pawn']

# %% [markdown]
# Selanjutnya kita perlu melihat berapa banyak gambar pada setiap direktori. Dari output dapat dilihat bahwa jumlah sampel pada tiap direktori berbeda. Perlu diperhatikan juga dataset ini berukuran sangat kecil sehingga performa dari model mungkin tidak akan terlalu baik. Kita akan mencoba menggunakan augmentasi gambar untuk mengatasi masalah ini.

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %% [markdown]
# Kita dapat melihat contoh dari sebuah gambar pada dataset dengan menjalankan kode di bawah.

# %%
from keras.preprocessing import image #this library not work, so I use tf to load image
from tensorflow.keras.utils import load_img
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %% [markdown]
# Selanjutnya kita impor ImageDataGenerator dan aplikasikan augmentasi gambar pada dataset kita. Perhatikan bahwa ada parameter yaitu validation split. Parameter ini akan dijelaskan pada paragraf berikutnya.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
 
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %% [markdown]
# Dataset yang kita miliki hanya terdiri dari 1 buah direktori dan tidak terbagi menjadi direktori training dan testing. Tapi tenang, dengan ImageDataGenerator kita tidak perlu susah payah membagi direktori secara manual, cukup dengan menggunakan parameter validation_split yang disebut pada paragraf sebelumnya. Dengan parameter tersebut, kita hanya cukup memberi tahu ImageDataGenerator mana data untuk training dan mana data untuk testing dengan menambahkan parameter subset dengan nilai training atau validation.

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %% [markdown]
# Selanjutnya, kita buat arsitektur dari model kita. Untuk model ini kita menggunakan 3 lapis convolution dan 2 hidden layer dengan 512 dan 256 buah unit perseptron.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')  
])

# %% [markdown]
# Setelah arsitektur dibuat, tentukan optimizer dan loss yang akan digunakan model

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# Terakhir, panggil fungsi fit untuk melatih model kita.

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 19s - loss: 1.8937 - accuracy: 0.1784 - val_loss: 1.7870 - val_accuracy: 0.2308 - 19s/epoch - 302ms/step
# Epoch 2/50
# 63/63 - 10s - loss: 1.7878 - accuracy: 0.2004 - val_loss: 1.7849 - val_accuracy: 0.2308 - 10s/epoch - 154ms/step
# Epoch 3/50
# 63/63 - 9s - loss: 1.7817 - accuracy: 0.1944 - val_loss: 1.7647 - val_accuracy: 0.2500 - 9s/epoch - 145ms/step
# Epoch 4/50
# 63/63 - 10s - loss: 1.7559 - accuracy: 0.2084 - val_loss: 1.7455 - val_accuracy: 0.2692 - 10s/epoch - 160ms/step
# Epoch 5/50
# 63/63 - 9s - loss: 1.7295 - accuracy: 0.2465 - val_loss: 1.7620 - val_accuracy: 0.2692 - 9s/epoch - 145ms/step
# Epoch 6/50
# 63/63 - 10s - loss: 1.6981 - accuracy: 0.2926 - val_loss: 1.7136 - val_accuracy: 0.2308 - 10s/epoch - 154ms/step
# Epoch 7/50
# 63/63 - 9s - loss: 1.6796 - accuracy: 0.3066 - val_loss: 1.6482 - val_accuracy: 0.3077 - 9s/epoch - 145ms/step
# Epoch 8/50
# 63/63 - 9s - loss: 1.6508 - accuracy: 0.3106 - val_loss: 1.7989 - val_accuracy: 0.2500 - 9s/epoch - 144ms/step
# Epoch 9/50
# 63/63 - 9s - loss: 1.6084 - accuracy: 0.3246 - val_loss: 1.5643 - val_accuracy: 0.4231 - 9s/epoch - 145ms/step
# Epoch 10/50
# 63/63 - 9s - loss: 1.5794 - accuracy: 0.3747 - val_loss: 1.6261 - val_accuracy: 0.4615 - 9s/epoch - 147ms/step
# Epoch 11/50
# 63/63 - 10s - loss: 1.5463 - accuracy: 0.3768 - val_loss: 1.5927 - val_accuracy: 0.4038 - 10s/epoch - 160ms/step
# Epoch 12/50
# 63/63 - 9s - loss: 1.4873 - accuracy: 0.4028 - val_loss: 1.6144 - val_accuracy: 0.3462 - 9s/epoch - 147ms/step
# Epoch 13/50
# 63/63 - 9s - loss: 1.4774 - accuracy: 0.3968 - val_loss: 1.7139 - val_accuracy: 0.3462 - 9s/epoch - 147ms/step
# Epoch 14/50
# 63/63 - 9s - loss: 1.4194 - accuracy: 0.4609 - val_loss: 1.5553 - val_accuracy: 0.3654 - 9s/epoch - 146ms/step
# Epoch 15/50
# 63/63 - 9s - loss: 1.3610 - accuracy: 0.4749 - val_loss: 1.4675 - val_accuracy: 0.3077 - 9s/epoch - 146ms/step
# Epoch 16/50
# 63/63 - 9s - loss: 1.3469 - accuracy: 0.4669 - val_loss: 1.4187 - val_accuracy: 0.4808 - 9s/epoch - 146ms/step
# Epoch 17/50
# 63/63 - 9s - loss: 1.2233 - accuracy: 0.5190 - val_loss: 1.4083 - val_accuracy: 0.4615 - 9s/epoch - 147ms/step
# Epoch 18/50
# 63/63 - 9s - loss: 1.2415 - accuracy: 0.5090 - val_loss: 1.6301 - val_accuracy: 0.3846 - 9s/epoch - 145ms/step
# Epoch 19/50
# 63/63 - 9s - loss: 1.2140 - accuracy: 0.5511 - val_loss: 1.5388 - val_accuracy: 0.3846 - 9s/epoch - 145ms/step
# Epoch 20/50
# 63/63 - 9s - loss: 1.1121 - accuracy: 0.5952 - val_loss: 1.6644 - val_accuracy: 0.3654 - 9s/epoch - 148ms/step
# Epoch 21/50
# 63/63 - 10s - loss: 1.0562 - accuracy: 0.5731 - val_loss: 1.6070 - val_accuracy: 0.3846 - 10s/epoch - 160ms/step
# Epoch 22/50
# 63/63 - 9s - loss: 1.1148 - accuracy: 0.5651 - val_loss: 1.3597 - val_accuracy: 0.5192 - 9s/epoch - 148ms/step
# Epoch 23/50
# 63/63 - 9s - loss: 1.0311 - accuracy: 0.6152 - val_loss: 1.3847 - val_accuracy: 0.4231 - 9s/epoch - 147ms/step
# Epoch 24/50
# 63/63 - 9s - loss: 1.0293 - accuracy: 0.6132 - val_loss: 1.5318 - val_accuracy: 0.4423 - 9s/epoch - 146ms/step
# Epoch 25/50
# 63/63 - 9s - loss: 0.9738 - accuracy: 0.6553 - val_loss: 1.5247 - val_accuracy: 0.4231 - 9s/epoch - 150ms/step
# Epoch 26/50
# 63/63 - 9s - loss: 0.9382 - accuracy: 0.6513 - val_loss: 1.5994 - val_accuracy: 0.4615 - 9s/epoch - 147ms/step
# Epoch 27/50
# 63/63 - 9s - loss: 0.9259 - accuracy: 0.6453 - val_loss: 1.4027 - val_accuracy: 0.5000 - 9s/epoch - 144ms/step
# Epoch 28/50
# 63/63 - 9s - loss: 0.9082 - accuracy: 0.6633 - val_loss: 1.5549 - val_accuracy: 0.4231 - 9s/epoch - 145ms/step
# Epoch 29/50
# 63/63 - 9s - loss: 0.8582 - accuracy: 0.6814 - val_loss: 1.5658 - val_accuracy: 0.4423 - 9s/epoch - 148ms/step
# Epoch 30/50
# 63/63 - 10s - loss: 0.8271 - accuracy: 0.7094 - val_loss: 1.6644 - val_accuracy: 0.4423 - 10s/epoch - 164ms/step
# Epoch 31/50
# 63/63 - 9s - loss: 0.8324 - accuracy: 0.7014 - val_loss: 1.6203 - val_accuracy: 0.4038 - 9s/epoch - 148ms/step
# Epoch 32/50
# 63/63 - 9s - loss: 0.8339 - accuracy: 0.7094 - val_loss: 1.4489 - val_accuracy: 0.4231 - 9s/epoch - 146ms/step
# Epoch 33/50
# 63/63 - 9s - loss: 0.7443 - accuracy: 0.7054 - val_loss: 1.4401 - val_accuracy: 0.4615 - 9s/epoch - 147ms/step
# Epoch 34/50
# 63/63 - 9s - loss: 0.6843 - accuracy: 0.7515 - val_loss: 1.6350 - val_accuracy: 0.4231 - 9s/epoch - 146ms/step
# Epoch 35/50
# 63/63 - 9s - loss: 0.7252 - accuracy: 0.7375 - val_loss: 1.7643 - val_accuracy: 0.4615 - 9s/epoch - 145ms/step
# Epoch 36/50
# 63/63 - 9s - loss: 0.7069 - accuracy: 0.7756 - val_loss: 1.6608 - val_accuracy: 0.3846 - 9s/epoch - 148ms/step
# Epoch 37/50
# 63/63 - 9s - loss: 0.6263 - accuracy: 0.7916 - val_loss: 1.7619 - val_accuracy: 0.3654 - 9s/epoch - 145ms/step
# Epoch 38/50
# 63/63 - 9s - loss: 0.6502 - accuracy: 0.7695 - val_loss: 1.5630 - val_accuracy: 0.5192 - 9s/epoch - 147ms/step
# Epoch 39/50
# 63/63 - 10s - loss: 0.6709 - accuracy: 0.7796 - val_loss: 1.6253 - val_accuracy: 0.4808 - 10s/epoch - 163ms/step
# Epoch 40/50
# 63/63 - 9s - loss: 0.5469 - accuracy: 0.7996 - val_loss: 1.4793 - val_accuracy: 0.5385 - 9s/epoch - 147ms/step
# Epoch 41/50
# 63/63 - 9s - loss: 0.5152 - accuracy: 0.7956 - val_loss: 1.6810 - val_accuracy: 0.4615 - 9s/epoch - 147ms/step
# Epoch 42/50
# 63/63 - 9s - loss: 0.5250 - accuracy: 0.8036 - val_loss: 1.7870 - val_accuracy: 0.4231 - 9s/epoch - 148ms/step
# Epoch 43/50
# 63/63 - 9s - loss: 0.6212 - accuracy: 0.7976 - val_loss: 1.4167 - val_accuracy: 0.4423 - 9s/epoch - 148ms/step
# Epoch 44/50
# 63/63 - 10s - loss: 0.5015 - accuracy: 0.8196 - val_loss: 1.4585 - val_accuracy: 0.5000 - 10s/epoch - 161ms/step
# Epoch 45/50
# 63/63 - 9s - loss: 0.5310 - accuracy: 0.8116 - val_loss: 1.6934 - val_accuracy: 0.4615 - 9s/epoch - 147ms/step
# Epoch 46/50
# 63/63 - 9s - loss: 0.6774 - accuracy: 0.7816 - val_loss: 1.4728 - val_accuracy: 0.4231 - 9s/epoch - 147ms/step
# Epoch 47/50
# 63/63 - 9s - loss: 0.5907 - accuracy: 0.7735 - val_loss: 1.4308 - val_accuracy: 0.4423 - 9s/epoch - 150ms/step
# Epoch 48/50
# 63/63 - 10s - loss: 0.4372 - accuracy: 0.8297 - val_loss: 1.4514 - val_accuracy: 0.5577 - 10s/epoch - 163ms/step
# Epoch 49/50
# 63/63 - 9s - loss: 0.4342 - accuracy: 0.8297 - val_loss: 2.0559 - val_accuracy: 0.3654 - 9s/epoch - 146ms/step
# Epoch 50/50
# 63/63 - 9s - loss: 0.5147 - accuracy: 0.8216 - val_loss: 2.0183 - val_accuracy: 0.3462 - 9s/epoch - 145ms/step

# %% [markdown]
# Anda juga dapat membuat plot akurasi dari model menggunakan kode berikut.

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Untuk membuat plot loss Anda cukup menjalankan kode berikut.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Selamat, Anda berhasil mengembangkan model untuk mengklasifikasikan dataset yang sangat variatif. Akurasi yang didapat sekitar 50% di mana model akan membuat sekitar 50 persen prediksi yang salah.
#
# Setelah ini, saya akan menggunakan transfer learning dan melihat bagaimana teknik ini meningkatkan akurasi dari model ini.

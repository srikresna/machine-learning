# %%
#import pandas dan tensor flow
import tensorflow as tf
import pandas as pd
import numpy as np
import zipfile
import matplotlib.pyplot as plt
import datetime
import random
import os

import nltk, os, re, string

from keras.layers import Input, LSTM, Bidirectional, SpatialDropout1D, Dropout, Flatten, Dense, Embedding, BatchNormalization
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.preprocessing.sequence import pad_sequences

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn

nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# ### Pre Processing Data

# %%
# Import Data set yang akan digunakan
df = pd.read_csv('bbc-news-data.csv',sep='\t')

df.head()
# Out:
#    category filename                              title  \
# 0  business  001.txt  Ad sales boost Time Warner profit
# 1  business  002.txt   Dollar gains on Greenspan speech
# 2  business  003.txt  Yukos unit buyer faces loan claim
# 3  business  004.txt  High fuel prices hit BA's profits
# 4  business  005.txt  Pernod takeover talk lifts Domecq
#
#                                              content
# 0   Quarterly profits at US media giant TimeWarne...
# 1   The dollar has hit its highest level against ...
# 2   The owners of embattled Russian oil giant Yuk...
# 3   British Airways has blamed high fuel prices f...
# 4   Shares in UK drinks and food firm Allied Dome...

# %%
# Cek jumlah data yang dimiliki masing masing sentiment
df['category'].value_counts()
# Out:
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: category, dtype: int64

# %%
df.isnull().sum()
# Out:
# category    0
# filename    0
# title       0
# content     0
# dtype: int64

# %%
df.shape
# Out:
# (2225, 4)

# %%
#delete unused column

df = df.drop(columns = 'filename')

# %% [markdown]
# ##### Case Folding & Cleaning Data

# %%
# function to clean the tweets
import re
import string
def cleanTxt(text):
    text = re.sub(r'@\w+|#\w+', '', text)
    text = re.sub('#', '', text)
    text = re.sub('RT[\s]+', '', text)
    text = re.sub('\w+:\/\/\S+', '', text)
    text = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text)
    #remove punctuation
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = text.strip()
    text = re.sub('<.*?>', ' ', text)
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub("\n", " ", text)
    text = re.sub(r"\b\w\b", " ", text)
    text = ' '.join(text.split())
    return text

# %%
# removing functuation
def cleaner(data):
    return(data.translate(str.maketrans('','', string.punctuation)))
df['title'] = df['title'].apply(lambda x: cleaner(x))
df['content'] = df['content'].apply(lambda x: cleaner(x))

## lematization
lemmatizer = WordNetLemmatizer()

def lem(data):
    pos_dict = {'N': wn.NOUN, 'V': wn.VERB, 'J': wn.ADJ, 'R': wn.ADV}
    return(' '.join([lemmatizer.lemmatize(w,pos_dict.get(t, wn.NOUN)) for w,t in nltk.pos_tag(data.split())]))
df['title'] = df['title'].apply(lambda x: lem(x))
df['content'] = df['content'].apply(lambda x: lem(x))

# removing number
def rem_numbers(data):
    return re.sub('[0-9]+','',data)
df['title'].apply(rem_numbers)
df['content'].apply(rem_numbers)

# removing stopword
st_words = set(stopwords.words('english'))
def stopword(data):
    return(' '.join([w for w in data.split() if w not in st_words ]))
df['title'] = df['title'].apply(lambda x: stopword(x))
df['content'] = df['content'].apply(lambda x: stopword(x))

# %%
# MERGE JUDUL & ISI BERITA
df['merged_text'] = df['title'] + ' ' + df['content']

# DO PREPROCESSING
df['merged_text_pre'] = df['merged_text'].apply(cleanTxt)

# %%
# view data after cleansing
df.head(10)
# Out:
#    category                             title  \
# 0  business  Ad sale boost Time Warner profit
# 1  business      Dollar gain Greenspan speech
# 2  business  Yukos unit buyer face loan claim
# 3  business    High fuel price hit BAs profit
# 4  business  Pernod takeover talk lift Domecq
# 5  business   Japan narrowly escape recession
# 6  business         Jobs growth still slow US
# 7  business        India call fair trade rule
# 8  business      Ethiopias crop production 24
# 9  business   Court reject 280bn tobacco case
#
#                                              content  \
# 0  Quarterly profit US medium giant TimeWarner ju...
# 1  The dollar ha hit highest level euro almost th...
# 2  The owner embattled Russian oil giant Yukos as...
# 3  British Airways ha blamed high fuel price 40 d...
# 4  Shares UK drink food firm Allied Domecq risen ...
# 5  Japans economy teetered brink technical recess...
# 6  The US created fewer job expected January fall...
# 7  India attends G7 meeting seven leading industr...
# 8  Ethiopia produced 1427 million tonne crop 2004...
# 9  A US government claim accusing country biggest...
#
#                                          merged_text  \
# 0  Ad sale boost Time Warner profit Quarterly pro...
# 1  Dollar gain Greenspan speech The dollar ha hit...
# 2  Yukos unit buyer face loan claim The owner emb...
# 3  High fuel price hit BAs profit British Airways...
# 4  Pernod takeover talk lift Domecq Shares UK dri...
# 5  Japan narrowly escape recession Japans economy...
# 6  Jobs growth still slow US The US created fewer...
# 7  India call fair trade rule India attends G7 me...
# 8  Ethiopias crop production 24 Ethiopia produced...
# 9  Court reject 280bn tobacco case A US governmen...
#
#                                      merged_text_pre
# 0  ad sale boost time warner profit quarterly pro...
# 1  dollar gain greenspan speech the dollar ha hit...
# 2  yukos unit buyer face loan claim the owner emb...
# 3  high fuel price hit bas profit british airways...
# 4  pernod takeover talk lift domecq shares uk dri...
# 5  japan narrowly escape recession japans economy...
# 6  jobs growth still slow us the us created fewer...
# 7  india call fair trade rule india attends meeti...
# 8  ethiopias crop production ethiopia produced mi...
# 9  court reject bn tobacco case us government cla...

# %% [markdown]
# ##Balance the data

# %%
# # data category one-hot-encoding
# category = pd.get_dummies(dataframe.category)
# dataframe_cat = pd.concat([dataframe, category], axis=1)
# dataframe_cat = dataframe_cat.drop(columns='category')
# dataframe_cat.tail(10)


# data category one-hot-encoding
category = pd.get_dummies(df.category)
df_cat = pd.concat([df, category], axis=1)
df_cat = df_cat.drop(columns='category')
df_cat.tail(10)
# Out:
#                                  title  \
# 2215  Broadband fuel online expression
# 2216       Savvy searcher fail spot ad
# 2217             TVs future phone line
# 2218          Cebit fever take Hanover
# 2219   New console promise big problem
# 2220      BT program beat dialler scam
# 2221      Spam email tempt net shopper
# 2222                   Be careful code
# 2223   US cyber security chief resigns
# 2224              Losing online gaming
#
#                                                 content  \
# 2215  Fast web access encouraging people express onl...
# 2216  Internet search engine user odd mix naive soph...
# 2217  Internet TV ha talked since start web know But...
# 2218  Thousands product ten thousand visitor make Ce...
# 2219  Making game future console require graphic art...
# 2220  BT introducing two initiative help beat rogue ...
# 2221  Computer user across world continue ignore sec...
# 2222  A new European directive could put software wr...
# 2223  The man making sure US computer network safe s...
# 2224  Online role playing game timeconsuming enthral...
#
#                                             merged_text  \
# 2215  Broadband fuel online expression Fast web acce...
# 2216  Savvy searcher fail spot ad Internet search en...
# 2217  TVs future phone line Internet TV ha talked si...
# 2218  Cebit fever take Hanover Thousands product ten...
# 2219  New console promise big problem Making game fu...
# 2220  BT program beat dialler scam BT introducing tw...
# 2221  Spam email tempt net shopper Computer user acr...
# 2222  Be careful code A new European directive could...
# 2223  US cyber security chief resigns The man making...
# 2224  Losing online gaming Online role playing game ...
#
#                                         merged_text_pre  business  \
# 2215  broadband fuel online expression fast web acce...         0
# 2216  savvy searcher fail spot ad internet search en...         0
# 2217  tvs future phone line internet tv ha talked si...         0
# 2218  cebit fever take hanover thousands product ten...         0
# 2219  new console promise big problem making game fu...         0
# 2220  bt program beat dialler scam bt introducing tw...         0
# 2221  spam email tempt net shopper computer user acr...         0
# 2222  be careful code new european directive could p...         0
# 2223  us cyber security chief resigns the man making...         0
# 2224  losing online gaming online role playing game ...         0
#
#       entertainment  politics  sport  tech
# 2215              0         0      0     1
# 2216              0         0      0     1
# 2217              0         0      0     1
# 2218              0         0      0     1
# 2219              0         0      0     1
# 2220              0         0      0     1
# 2221              0         0      0     1
# 2222              0         0      0     1
# 2223              0         0      0     1
# 2224              0         0      0     1

# %%
# change dataframe value to numpy array
news = df_cat['merged_text_pre'].values
label = df_cat[['business', 'entertainment', 'politics', 'sport', 'tech']].values

# %%
from sklearn.model_selection import train_test_split
data_latih, data_validasi, label_latih, label_validasi = train_test_split(news, label, test_size = 0.2)

data_latih.shape, label_latih.shape, data_validasi.shape, label_validasi.shape
# Out:
# ((1780,), (1780, 5), (445,), (445, 5))

# %%
from collections import Counter

Counter(np.argmax(label_latih, axis=1))
# Out:
# Counter({2: 327, 3: 406, 1: 309, 0: 411, 4: 327})

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=123)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


tokenizer = Tokenizer(num_words=10000, oov_token='<oov>')
tokenizer.fit_on_texts(data_latih)
tokenizer.fit_on_texts(data_validasi)


sekuens_latih = tokenizer.texts_to_sequences(data_latih)
sekuens_validasi = tokenizer.texts_to_sequences(data_validasi)

padded_latih = pad_sequences(sekuens_latih, padding = 'post', maxlen = 15, truncating ='post')
padded_validasi = pad_sequences(sekuens_validasi, padding = 'post', maxlen = 15, truncating ='post')

# %%
# buat data menjadi balance
padded_latih, label_latih = sm.fit_resample(padded_latih, label_latih)

# cek label data latih
Counter(np.argmax(label_latih, axis=1))
# Out:
# Counter({2: 411, 3: 411, 1: 411, 0: 411, 4: 411})

# %%
# model
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=10000, output_dim=512),
    tf.keras.layers.LSTM(512),
    tf.keras.layers.Dense(2048, activation='relu'),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(5, activation='softmax')
])
model.compile(optimizer= Adam(learning_rate = 0.001) , metrics=['accuracy'], loss='categorical_crossentropy',)
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_23 (Embedding)    (None, None, 512)         5120000
#
#  lstm_23 (LSTM)              (None, 512)               2099200
#
#  dense_66 (Dense)            (None, 2048)              1050624
#
#  dense_67 (Dense)            (None, 1024)              2098176
#
#  dense_68 (Dense)            (None, 512)               524800
#
#  dense_69 (Dense)            (None, 256)               131328
#
#  dropout_28 (Dropout)        (None, 256)               0
#
#  dense_70 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 11025413 (42.06 MB)
# Trainable params: 11025413 (42.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# callback
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9 and logs.get('val_accuracy')>0.90):
      self.model.stop_training = True
      print("\nThe accuracy of the training set and the validation set has reached > 90%!")
callbacks = myCallback()

# %%
# model fit
history = model.fit(padded_latih, label_latih, epochs=50,
                    validation_data=(padded_validasi, label_validasi), verbose=1,  callbacks=[callbacks])
# Out:
# Epoch 1/50
# 79/79 [==============================] - 8s 69ms/step - loss: 1.1591 - accuracy: 0.5156 - val_loss: 0.8461 - val_accuracy: 0.7556
# Epoch 2/50
# 79/79 [==============================] - 2s 29ms/step - loss: 0.4603 - accuracy: 0.8420 - val_loss: 0.4755 - val_accuracy: 0.8667
# Epoch 3/50
# 79/79 [==============================] - 2s 21ms/step - loss: 0.1798 - accuracy: 0.9504 - val_loss: 0.3814 - val_accuracy: 0.8889
# Epoch 4/50
# 79/79 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9820
# The accuracy of the training set and the validation set has reached > 90%!
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0807 - accuracy: 0.9820 - val_loss: 0.2968 - val_accuracy: 0.9333

# %%
import pandas as pd

# %%
df = pd.read_csv('kampus.csv')
df
# Out:
#                       keyword  \
# 0          Universitas Malang
# 1          Universitas Malang
# 2          Universitas Malang
# 3          Universitas Malang
# 4          Universitas Malang
# ..                        ...
# 397  Sekolah Tinggi di Malang
# 398  Sekolah Tinggi di Malang
# 399  Sekolah Tinggi di Malang
# 400  Sekolah Tinggi di Malang
# 401  Sekolah Tinggi di Malang
#
#                                                  Title Reviews Review_points  \
# 0                            Universitas Negeri Malang    4002           4.7
# 1           The Rectorate of Universitas Negeri Malang     443           4.8
# 2                 Universitas Negeri Malang, Kampus II     204           4.6
# 3    Maulana Malik Ibrahim State Islamic University...    2113           4.6
# 4                         Islamic University of Malang    1796           4.7
# ..                                                 ...     ...           ...
# 397                                        stpp malang       6           4.7
# 398  Masterprima Sawojajar Bimbel | CPNS | KEDINASA...     130             5
# 399                                   De Access Malang     118             5
# 400                           Bina Avia Persada Malang      26             5
# 401                Jurusan Teknik Informatika Polinema       2             5
#
#                                                Address Country         City  \
# 0    Jl. Cakrawala No.5, Sumbersari, Kec. Lowokwaru...      ID  Malang City
# 1    Jl. Semarang No.5, Sumbersari, Kec. Lowokwaru,...      ID  Malang City
# 2    Jl. Ki Ageng Gribig No.45, Madyopuro, Kec. Ked...      ID  Malang City
# 3    Jl. Gajayana No.50, Dinoyo, Kec. Lowokwaru, Ko...      ID  Malang City
# 4    Jalan Mayjen Haryono No.193, Dinoyo, Kec. Lowo...      ID  Malang City
# ..                                                 ...     ...          ...
# 397  2J98+3RV, Bareng, Klojen, Malang City, East Ja...      ID  Malang City
# 398  H2 E54, Jl. Danau Bratan Raya, Madyopuro, Kec....      ID  Malang City
# 399  II, No, T Jl. Esberg No.1 B, Karangbesuki, Suk...      ID  Malang City
# 400  Ruko Tlogomas, Jl. Raya Tlogomas No.23 Square ...      ID  Malang City
# 401  Jl. MT. Haryono No.72, Ketawanggede, Kec. Lowo...      ID  Malang City
#
#          State                            Website              Phone  ...  \
# 0    East Java               http://www.um.ac.id/     +62 341 551312  ...
# 1    East Java               http://www.um.ac.id/     +62 341 551312  ...
# 2    East Java               http://www.um.ac.id/     +62 341 712192  ...
# 3    East Java                                NaN     +62 341 551354  ...
# 4    East Java                                NaN     +62 341 551932  ...
# ..         ...                                ...                ...  ...
# 397  East Java                                NaN                NaN  ...
# 398  East Java           https://masterprima.com/  +62 821-1000-3955  ...
# 399  East Java  http://www.deaccess.sch.id/malang   +62 817-5498-888  ...
# 400  East Java    http://www.binaaviapersada.com/  +62 857-5294-4744  ...
# 401  East Java         http://www.polinema.ac.id/                NaN  ...
#
#                     Open_Time_Friday                    Open_Time_Saturday  \
# 0    Friday 7 AM–2:30 PM  2024-10-18           Saturday Closed  2024-10-19
# 1       Friday 8 AM–3 PM  2024-10-18           Saturday Closed  2024-10-19
# 4    Jalan Mayjen Haryono No.193, Dinoyo, Kec. Lowo...      ID  Malang City
# ..                                                 ...     ...          ...
# 397  2J98+3RV, Bareng, Klojen, Malang City, East Ja...      ID  Malang City
# 398  H2 E54, Jl. Danau Bratan Raya, Madyopuro, Kec....      ID  Malang City
# 399  II, No, T Jl. Esberg No.1 B, Karangbesuki, Suk...      ID  Malang City
# 400  Ruko Tlogomas, Jl. Raya Tlogomas No.23 Square ...      ID  Malang City
# 401  Jl. MT. Haryono No.72, Ketawanggede, Kec. Lowo...      ID  Malang City
#
#          State                            Website              Phone  ...  \
# 0    East Java               http://www.um.ac.id/     +62 341 551312  ...
# 1    East Java               http://www.um.ac.id/     +62 341 551312  ...
# 2    East Java               http://www.um.ac.id/     +62 341 712192  ...
# 3    East Java                                NaN     +62 341 551354  ...
# 4    East Java                                NaN     +62 341 551932  ...
# ..         ...                                ...                ...  ...
# 397  East Java                                NaN                NaN  ...
# 398  East Java           https://masterprima.com/  +62 821-1000-3955  ...
# 399  East Java  http://www.deaccess.sch.id/malang   +62 817-5498-888  ...
# 400  East Java    http://www.binaaviapersada.com/  +62 857-5294-4744  ...
# 401  East Java         http://www.polinema.ac.id/                NaN  ...
#
#                     Open_Time_Friday                    Open_Time_Saturday  \
# 0    Friday 7 AM–2:30 PM  2024-10-18           Saturday Closed  2024-10-19
# 1       Friday 8 AM–3 PM  2024-10-18           Saturday Closed  2024-10-19
# 2    Friday 7 AM–2:30 PM  2024-10-18           Saturday Closed  2024-10-19
# 3                                NaN                                   NaN
# 4    Friday 8 AM–5:10 PM  2024-10-18     Saturday 8 AM–5:10 PM  2024-10-19
# ..                               ...                                   ...
# 397  Friday 7:30 AM–4 PM  2024-10-18           Saturday Closed  2024-10-19
# 398  Friday 8 AM–7:30 PM  2024-10-18  Saturday 8:30 AM–3:30 PM  2024-10-19
# 399     Friday 8 AM–4 PM  2024-10-18        Saturday 8 AM–4 PM  2024-10-19
# 400     Friday 8 AM–4 PM  2024-10-18           Saturday Closed  2024-10-19
# 401     Friday 7 AM–5 PM  2024-10-18           Saturday Closed  2024-10-19
#
#               Open_Time_Sunday  \
# 0    Sunday Closed  2024-10-20
# 1    Sunday Closed  2024-10-20
# 2    Sunday Closed  2024-10-20
# 3                          NaN
# 4    Sunday Closed  2024-10-20
# ..                         ...
# 397  Sunday Closed  2024-10-20
# 398  Sunday Closed  2024-10-20
# 399  Sunday Closed  2024-10-20
# 400  Sunday Closed  2024-10-20
# 401  Sunday Closed  2024-10-20
#
#                                   Popular_times_Monday  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 397                                                NaN
# 398  0% busy at 6 AM;0% busy at 7 AM;0% busy at 8 A...
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
#
#                                  Popular_times_Tuesday  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 397                                                NaN
# 398  0% busy at 6 AM;0% busy at 7 AM;0% busy at 8 A...
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
#
#                                Popular_times_Wednesday  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 397                                                NaN
# 398  0% busy at 6 AM;0% busy at 7 AM;0% busy at 8 A...
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
#
#                                 Popular_times_Thursday  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 397                                                NaN
# 398  0% busy at 6 AM;0% busy at 7 AM;0% busy at 8 A...
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
#
#                                   Popular_times_Friday  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 397                                                NaN
# 398  0% busy at 6 AM;0% busy at 7 AM;22% busy at 8 ...
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
#
#                                 Popular_times_Saturday Popular_times_Sunday
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 397                                                NaN                  NaN
# 398  0% busy at 6 AM;0% busy at 7 AM;44% busy at 8 ...       Closed on day7
# 399                                                NaN                  NaN
# 400                                                NaN                  NaN
# 401                                                NaN                  NaN
#
# [247 rows x 42 columns]

# %%
import re

kecamatan_dict = {
    "Blimbing": ["Arjosari", "Balearjosari", "Blimbing", "Bunulrejo", "Jodipan", "Kesatrian", "Pandanwangi", "Polehan", "Polowijen", "Purwantoro", "Purwodadi"],
    "Kedungkandang": ["Arjowinangun", "Bumiayu", "Buring", "Cemorokandang", "Kedungkandang", "Kotalama", "Lesanpuro", "Madyopuro", "Mergosono", "Sawojajar", "Tlogowaru", "Wonokoyo"],
    "Klojen": ["Bareng", "Gadingasri", "Kasin", "Kauman", "Kiduldalem", "Klojen", "Oro-Oro Dowo", "Penanggungan", "Rampal Celaket", "Samaan", "Sukoharjo"],
    "Lowokwaru": ["Dinoyo", "Jatimulyo", "Ketawanggede", "Lowokwaru", "Merjosari", "Mojolangu", "Sumbersari", "Tasikmadu", "Tlogomas", "Tulusrejo", "Tunggulwulung", "Tunjungsekar"],
    "Sukun": ["Bakalankrajan", "Bandulan", "Bandungrejosari", "Ciptomulyo", "Gadang", "Karangbesuki", "Kebonsari", "Mulyorejo", "Pisangcandi", "Sukun", "Tanjungrejo"]
}

kelurahan_to_kecamatan = {kelurahan: kecamatan for kecamatan, kelurahans in kecamatan_dict.items() for kelurahan in kelurahans}

def extract_kelurahan_from_address(address):
    if isinstance(address, str):
        for kelurahan in kelurahan_to_kecamatan:
            if re.search(r'\b' + re.escape(kelurahan) + r'\b', address, re.IGNORECASE):
                return kelurahan
    return None

def extract_kecamatan_from_address(address):
    kelurahan = extract_kelurahan_from_address(address)
    if kelurahan:
        return kelurahan_to_kecamatan[kelurahan]
    if isinstance(address, str):
        for kecamatan in kecamatan_dict:
            if re.search(r'\b' + re.escape(kecamatan) + r'\b', address, re.IGNORECASE):
                return kecamatan
    return None

df['Kecamatan'] = df['Address'].apply(extract_kecamatan_from_address)
df['Kelurahan'] = df['Address'].apply(extract_kelurahan_from_address)
# Out:
# /tmp/ipykernel_110008/901482724.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kecamatan'] = df['Address'].apply(extract_kecamatan_from_address)
# /tmp/ipykernel_110008/901482724.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Kelurahan'] = df['Address'].apply(extract_kelurahan_from_address)

# %%
df['Kelurahan'].value_counts()

new_df = pd.DataFrame(df['Kelurahan'].value_counts())
new_df
# Out:
#                  count
# Kelurahan
# Lowokwaru           79
# Ketawanggede        33
# Dinoyo              26
# Klojen              20
# Sukun               17
# Blimbing            14
# Kedungkandang       10
# Kiduldalem           8
# Kauman               6
# Karangbesuki         4
# Bandungrejosari      2
# Bareng               2
# Jatimulyo            1
# Arjosari             1
# Mojolangu            1
# Bumiayu              1
# Merjosari            1
# Kasin                1
# Gadang               1
# Bandulan             1
# Kebonsari            1

# %%
new_df.to_csv('landmark_amount.csv')
